# %%
# %pip install SQLAlchemy psycopg2-binary
# SQLAlchemy -> To create connections to the database and perform operations
# psycopg2-binary -> To connect to PostgreSQL database

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Connect to db
connection_string = 'postgresql://username:password@localhost:5432/database_name'

# %%
df = pd.read_sql(sql='SELECT * FROM schema.table_name', con=connection_string)

# %%
df.to_csv('data.csv', index=False)
